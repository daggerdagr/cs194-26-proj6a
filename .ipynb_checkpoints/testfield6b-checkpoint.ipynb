# %%
# %pylab inline
from region.image import Image
from outputMake import *
from utils import *
from warping import *
from harris import *
from skimage.color import rgb2gray
import heapq

np.set_printoptions(suppress=True)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/reginaongowarsito/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/reginaongowarsito/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility
#   return f(*args, **kwds)

# %%
def dispPtsOnImg(im, results, tag=False):
    dispPtsOnImgRC(im, results[:, 0], results[:, 1], tag)

def dispPtsOnImgRC(im, rowInds, colInds, tag=False):
    assert len(rowInds) == len(colInds)
    plt.imshow(im)
    plt.plot(colInds, rowInds, 'bo')
    if tag:
        for ind in range(len(rowInds)):
            y, x = rowInds[ind], colInds[ind]
            plt.text(x, y, str(ind), bbox=dict(facecolor='blue', alpha=0.5))
            plt.text(x, y, "%d-%d" % (x,y), bbox=dict(facecolor='red', alpha=0.5))

# %%
imSproul0 = Image.fromPath("../curated_sample_imgs/lower_sproul/lower_sproul_00.jpg", 0.10)
imSproul0.readCoordsIn("../curated_sample_imgs/lower_sproul/2_lower_sproul_00.txt")
imSproul0.pts = imSproul0.pts * 0.25

imSproul1 = Image.fromPath("../curated_sample_imgs/lower_sproul/lower_sproul_01.jpg", 0.10)
imSproul1.readCoordsIn("../curated_sample_imgs/lower_sproul/2_lower_sproul_01.txt")
imSproul1.pts = imSproul0.pts * 0.25
# Out:
# /Users/reginaongowarsito/anaconda3/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
class HarrisInfo:
    def __init__(self, x, y, radius):
        self.x = x
        self.y = y
        self.radius = radius
    
    def __repr__(self):
        return "HarrisInfo(x: %s, y: %s, r: %s)" % (self.x, self.y, self.radius)
        
class CleanHeap:
    def __init__(self, key = lambda x: x):
        self.heap = []
        self.key = key
        
    def push(self, item):
        formattedItem = (self.key(item), item)
        heapq.heappush(self.heap, formattedItem)

    def pop(self):
        val, item = heapq.heappop(self.heap)
        return item
    
    def pushpop(self, item):
        formattedItem = (self.key(item), item)
        val, item = heapq.heappushpop(self.heap, formattedItem)
        return item
    
    def length(self):
        return len(self.heap)

class LimitedHeap2(CleanHeap):
    def __init__(self, limit, key = lambda x: x):
        self.limit = limit
        CleanHeap.__init__(self, key)
    
    def push(self, item):
        if self.length() < self.limit:
            CleanHeap.push(self, item)
        else:
            CleanHeap.pushpop(self, item)

class LimitedHeap:
    def __init__(self, limit):
        self.limit = limit
        self.heap = []
    
    def push(self, item):
        if len(self.heap) < self.limit:
            heapq.heappush(self.heap, item)
        else:
            heapq.heappushpop(self.heap, item)
    
    def pop(self):
        return heapq.heappop(self.heap)

# %%
im = imSproul0
desiredNs = 200
cRobust = 0.9

def findFeatures(im, desiredNs = 200, cRobust = 0.9):

    imArrGray = rgb2gray(im.imArr)

    allH, harrisCornersRowsCols = get_harris_corners(imArrGray[:,:])

    harrisCornersCoords = harrisCornersRowsCols.T

    harrisCornersStrengths = allH[harrisCornersRowsCols[0], harrisCornersRowsCols[1]]

    harrisCornersCoordsCt = len(harrisCornersCoords)
    rowOnes = np.array([[1, 0]] * harrisCornersCoordsCt).T
    colOnes = 1 - rowOnes
    valOnes = np.ones(harrisCornersCoordsCt)

    pointsHeap = LimitedHeap(limit = desiredNs)

    for i in range(harrisCornersCoordsCt):
        currRow, currCol = harrisCornersCoords[i]
        currVal = harrisCornersStrengths[i]
        
        diffRowsCols = harrisCornersRowsCols - (rowOnes * currRow + colOnes * currCol)
        norms = np.linalg.norm(diffRowsCols, axis=0)
        norms[i] = float("inf")

        diffCornerStrength = cRobust * harrisCornersStrengths - (valOnes * currVal)
        robustFailCoords = np.argwhere(diffCornerStrength <= 0)
        norms[robustFailCoords] = float("inf")

        closestCoordId = np.argmin(norms)
        minimRadius = norms[closestCoordId]
        if minimRadius == float("inf"):
            continue
        newHarrisInfo = HarrisInfo(currCol, currRow, norms[closestCoordId])

        pointsHeap.push((newHarrisInfo.radius, i, newHarrisInfo))
    
#     for i in heapq.nlargest(200, pointsHeap.heap):
#         print(i)
    # return
    finalNHarrisCoords = [res[2] for res in pointsHeap.heap]

    coordsRowsCols = np.array([[info.y, info.x] for info in finalNHarrisCoords]).T

    return coordsRowsCols

coordsRowsCols = findFeatures(imSproul1, 200, 0.9)
coordsRowsCols
# Out:
# array([[139, 130,  83, 150, 127, 137, 173,  76, 107, 140,  66,  79,  67,
#          71,  50,  56, 134,  63,  81, 122,  23,  26, 103,  46,  79, 124,
#          74,  96,  63, 174,  32,  71, 168, 140,  71,  23,  41,  99, 171,
#          73,  53, 156, 124, 111, 135, 119,  74,  44, 106,  28,  57,  86,
#         132,  58, 112,  95,  95, 115, 120,  59, 104,  60, 115,  51, 131,
#         109, 150,  76, 145, 115,  89, 102,  56,  67, 147,  73,  21, 131,
#          64,  83, 157,  57, 156,  59,  43, 151,  39,  99,  22, 155,  75,
#          34, 100, 136, 134,  87, 151, 145, 129, 170, 164, 170, 118, 107,
#         143, 113, 163, 103,  55,  38,  33,  88, 120, 162,  26,  88,  87,
#         105, 162,  55, 147, 115, 136,  86, 100, 148,  88,  63,  41, 114,
#         147,  55,  94,  76,  28,  56,  35, 168,  87,  34,  45,  87, 150,
#          30,  94,  21, 118, 167, 158, 147, 119, 174, 115, 157,  37,  60,
#          27,  50,  85, 175,  87,  25,  54, 135,  97,  74, 147, 117,  48,
#         144,  52,  61,  44,  99,  97, 155,  98,  28, 131, 131, 105,  87,
#         150,  61,  97, 164, 128, 149,  42, 102, 143,  27, 131, 143, 127,
#         164, 112,  51,  99, 126],
#        [ 48, 317,  38,  84,  44, 138,  33, 120, 204, 105,  68, 202,  47,
#         272, 194, 162, 127, 170,  82,  30,  29, 279, 151, 294,  90, 138,
#         168, 348, 154, 168, 270, 293, 150, 336, 209, 219,  60, 140, 379,
#         151, 286, 132, 206, 293, 138,  90, 305, 243, 215, 134, 136, 195,
#         243, 255, 228, 329, 332,  40, 274, 338, 368,  31, 196, 327,  88,
#         370, 199, 151, 382, 193, 264,  46, 312, 190, 253,  36,  95, 214,
#         122, 190,  38, 267, 251, 319, 125, 309,  58, 129, 107,  40, 355,
#         296, 167, 130, 182, 163,  28, 114, 231, 136, 194,  80, 229, 331,
#         347, 306, 367,  33, 213, 131, 233, 151, 319, 352, 134, 310, 135,
#         271, 112, 226, 156, 177, 276, 382, 104,  96, 251, 304, 310, 151,
#         141, 113,  76, 100, 363, 184,  79,  98, 307, 358, 343, 120,  50,
#         326,  32,  66, 259, 263, 132, 218, 222,  49, 132, 380, 204, 359,
#         180, 153, 338, 114, 277, 247,  80, 195, 292, 106, 238, 261, 277,
#         289,  63,  96, 371, 247, 228, 321, 199,  39, 373, 212,  35, 303,
#         172, 256, 355, 365, 106, 364, 145, 337, 264, 356, 254, 323,  21,
#         286, 231, 315, 180, 300]])

# %%
def t12():
    coordsRowsCols = findFeatures(imSproul1, 200, 0.9)
    dispPtsOnImgRC(imSproul0.imArr, coordsRowsCols[1], coordsRowsCols[0])

t12()

# %%
"""
given a point and a pic
grab an 40x40 patch from the surrounding area of the point
scale it down 8x8

"""

ptCoordXY = coordsRowsCols.T[1]
im = imSproul0

from skimage.transform import resize

def createDescriptor(ptCoordXY, im):
    assert ptCoordXY[0] < im.width, "input X coords too big for im width (%s): %s" % (im.width, ptCoordXY[0])
    assert ptCoordXY[1] < im.height, "input Y coords too big for im height (%s): %s" % (im.height, ptCoordXY[1])
    
    imArr = im.imArr
    # dispPtsOnImg(imArr, np.array([ptCoordXY]))
    origSize = 40
    finalSize = 8
    
#     print(ptCoordXY)
    
    rowBef = ptCoordXY[1] - origSize // 2
    adjRowBef = max(0, rowBef)
    rowAft = ptCoordXY[1] + origSize // 2
    adjRowAft = min(rowAft, im.height - 1)
    colBef = ptCoordXY[0] - origSize // 2
    adjColBef = max(0, colBef)
    colAft = ptCoordXY[0] + origSize // 2
    adjColAft = min(colAft, im.width - 1)
    
    retrievedPatch = imArr[adjRowBef : adjRowAft + 1, adjColBef : adjColAft + 1]
    
    retrievedPaddedPatch = np.zeros((rowAft - rowBef + 1, colAft - colBef + 1, 3))
    
    padRowInd = adjRowBef - rowBef
    padColInd = adjColBef - colBef
    
    
    rowSize, colSize = retrievedPatch.shape[:2]
    retrievedPaddedPatch[padRowInd : padRowInd + rowSize, padColInd : padColInd + colSize] = retrievedPatch
    
    finalPatch = resize(retrievedPaddedPatch, (finalSize, finalSize))
    
    inpAry = finalPatch
    origAve = inpAry.mean()
    newAry = (inpAry - origAve) * 1 / inpAry.std()
    
    return newAry

viewImage(createDescriptor(np.array([im.width - 1, im.height - 1]), im))
# Out:
# /Users/reginaongowarsito/anaconda3/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /Users/reginaongowarsito/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /Users/reginaongowarsito/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:1428: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
    featuresIm1RC = findFeatures(im1, desiredNs, cRobust)
    featuresIm2RC = findFeatures(im2, desiredNs, cRobust)
    # dispPtsOnImgRC(im2.imArr, featuresIm2[1], featuresIm2[0])
    
    """Note: featuresImN = X, Y"""
    
    flipCoords = lambda x: np.array([x[1], x[0]])
    
    featuresIm1XY = np.array(list(map(flipCoords, featuresIm1RC.T)))
    featuresIm2XY = np.array(list(map(flipCoords, featuresIm2RC.T)))
    
    
    subFn1 = lambda x: createDescriptor(x, im1)
    descriptorsIm1XY = np.array(list(map(subFn1, featuresIm1XY)))
    subFn2 = lambda x: createDescriptor(x, im2)
    descriptorsIm2XY = np.array(list(map(subFn2, featuresIm2XY)))
    
    flatDescIm1YX = np.array(list(map(np.ndarray.flatten, descriptorsIm1XY)))
    flatDescIm2YX = np.array(list(map(np.ndarray.flatten, descriptorsIm2XY)))

# %%
class AutoFeatureInfo:
    def __init__(self, featRC, featXY, descXY, flatDescXY):
        self.featRC = featRC
        self.featXY = featXY
        self.descXY = descXY
        self.flatDescXY = flatDescXY
        
def calcFnD(im1, desiredNs = 200, cRobust = 0.9):
    flipCoords = lambda x: np.array([x[1], x[0]])
    
    featRC = findFeatures(im1, desiredNs, cRobust)
    featXY = np.array(list(map(flipCoords, featRC.T)))
    subFn = lambda x: createDescriptor(x, im1)
    descXY = np.array(list(map(subFn, featXY)))
    flatDescXY = np.array(list(map(np.ndarray.flatten, descXY)))
    
    return AutoFeatureInfo(featRC, featXY, descXY, flatDescXY)

# %%
def auto_findH(im1Info, im2Info, outlierThreshold = 300):
    distResult = dist2(im1Info.flatDescXY, im2Info.flatDescXY)
    
    fPairs1t2 = np.array(findFeaturePairs(im1Info.featXY, im2Info.featXY, distResult))
    fPairs2t1 = np.array(findFeaturePairs(im2Info.featXY, im1Info.featXY, distResult.T))
    
    fPairsTotal = np.concatenate((fPairs1t2, np.flip(fPairs2t1, 1)), axis=0)
    
    bestH = None
    bestOutliersCt = None
    
    for combo in iter4(fPairsTotal):
        imAPts = combo[:, 0]
        imBPts = combo[:, 1]
        
        calculatedH = computeH(imAPts, imBPts)
        
        f1YXTransformed = transf(calculatedH, fPairsTotal[:, 0])
        
        ssdScores = np.sum((f1YXTransformed - fPairsTotal[:, 1]) ** 2, axis = 1)
        outliersCt = len(np.argwhere(ssdScores > outlierThreshold))
        
        if bestOutliersCt == None or outliersCt < bestOutliersCt:
            bestH = calculatedH
            bestOutliersCt = outliersCt

    return bestH

auto_findH(calcFnD(imSproul0), calcFnD(imSproul1))
# Out:
# /Users/reginaongowarsito/anaconda3/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /Users/reginaongowarsito/FA18_cs194-26/Proj6a/Proj6a/warping.py:159: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   x = np.linalg.lstsq(A, b)
# array([[  0.19410212,   0.08100282, 167.10091684],
#        [ -0.16316975,   0.78812613,  17.06162929],
#        [ -0.00199623,   0.00029985,   1.        ]])

# %%
def test2():
    print("calculating h1t0")
    h1t0 = auto_findH(imSproul1, imSproul0)
    print("calculating h0t1")
    h0t1 = auto_findH(imSproul0, imSproul1)
    print("h1t0:", h1t0)
    print("h0t1:", h0t1)
    print("h0t1 INV:", np.linalg.inv(h0t1))
    points = findFeatures(imSproul0, 200, 0.9)
    print("points:", points)
    # transformedPts = transf(h0t1, points.T)
    print("corners:", Image.getCorners(imSproul0))
    transformedPts = transf(h0t1, Image.getCorners(imSproul0))
    print(transformedPts)
    plt.close()
    dispPtsOnImgRC(imSproul1.imArr, transformedPts[:, 1], transformedPts[:, 0])
test2()
# Out:
# calculating h1t0
# /Users/reginaongowarsito/anaconda3/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /Users/reginaongowarsito/FA18_cs194-26/Proj6a/Proj6a/warping.py:159: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   x = np.linalg.lstsq(A, b)
# /Users/reginaongowarsito/FA18_cs194-26/Proj6a/Proj6a/warping.py:17: RuntimeWarning: divide by zero encountered in double_scalars
#   normCorner = np.dot(corner, 1 / (corner[2]))
# calculating h0t1
# h1t0: [[   1.65413777    0.05813462 -251.33453251]
#  [   0.16739873    1.46290009  -38.50797685]
#  [   0.00160662    0.00028008    1.        ]]
# h0t1: [[  0.19410212   0.08100282 167.10091684]
#  [ -0.16316975   0.78812613  17.06162929]
#  [ -0.00199623   0.00029985   1.        ]]
# h0t1 INV: [[   1.87698973   -0.07406713 -312.38299898]
#  [   0.30949764    1.26490953  -73.29875706]
#  [   0.00365409   -0.00052713    0.39839163]]
# points: [[140  80  45  65  55  23  88 133 171  48 174 133  82 161  30  77  93 121
#   136  90  25  75 142 152  23  89 124  54 121  43 136  91 159  92  73 158
#    68 146 166  59  82  22 101 102 170  33 164 101 169  42 113 169  58  95
#    82 113  50 119  75  35 160  52  54 104  73  30  94 148  32  59  59 102
#    63  77  70  70  38  57  59  40 138 155  38  64  34 111 145  41  69  24
#   107  37  78 103  56 175  38  56 151  91 108  57 144  48 163  46  59 112
#    23  30  66 162  24 134  41 111  39 140 121  33 161 101  22  80 139  77
#   160  57  24 122  64 143 105  76 121 171 137 102 159 116  70 145 158  93
#    54 122 147 123  52  55 103  78 157  35 156  26  26 166  92 119 156 132
#   104 108  32 141 150  27  28  52 155 165  59  44 135 170 121 173 137  27
#    52 153 102  93 122 102 146 133  90  23 150 103 146 152 119  38 147 145
#   152  34]
#  [266  98 363  71  56 106 339  42 138 149 281 285 226 306  53 379 303 100
#   118 112 231  22 102 163 319  23 154 382 192 213 123 359 294  38 150 221
#    74 220 173 263  86 268 102 378 199 247 107  91 355 217 227 225 245  74
#    65 290 203  34  26 366 380 166 247 249  73 378 320 186 278 190  39  47
#   364 367  51 215 267  95 276 219 364 282 344 366 317  88 217 377 136 138
#   183 191 300 277 246 255 142  43 358 234 162  78  41 153  28 375 325  68
#   296  65 377 236  37 243 330 197 190  79 133  25  45 208 151 210 195 317
#   240 341 344 212 125 281  41 270  35 373 256  61  59 313 249  57 319 175
#   225 381 134  58 253 178  39 335  81 236 256 217 198 154 230 213  84  25
#   254 331  66 197 310 116 177  66  80 272 292 222 296 271  81 125 304 175
#    27 237  45 255 183 143 154 240 377 216 307 117 335 233 336  81 117 330
#   106 101]]
# corners: [[  0   0]
#  [  0 195]
#  [402 195]
#  [402   0]]
# [[ 167.10091684   17.06162929]
#  [ 172.79320678  161.31414932]
#  [1019.28921092  410.76965625]
#  [1241.05454    -245.71298413]]

# %%
imgList = [imSproul0, imSproul1]

def autoWarp(imgList, imBase, outlierThreshold = 300):
    warpedResults = []
    for im in imgList:
        print("Calculating for:", im.name)
        print("Finding H, start.")
        if im.name == imBase.name:
            foundH = np.identity(3)
        else:
            foundH = auto_findH(calcFnD(im), calcFnD(imBase), outlierThreshold = outlierThreshold)
        print("Finding H, done.")
        # print("foundH:", foundH)
        warpInfo = warpWH(im, foundH)
        warpedResults.append(warpInfo)
    result = genImages(warpedResults)
    return result

printImage("test.png", alphaBlendingOutput(autoWarp(imgList, imSproul0)))
# Out:
# Calculating for: lower_sproul_00
# Finding H, start.
# Finding H, done.
# sourceCorners: [[  0   0]
#  [  0 195]
#  [402 195]
#  [402   0]]
# tfSourceCorners: [[  0.   0.]
#  [  0. 195.]
#  [402. 195.]
#  [402.   0.]]
# Calculating for: lower_sproul_01
# Finding H, start.
# /Users/reginaongowarsito/anaconda3/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /Users/reginaongowarsito/FA18_cs194-26/Proj6a/Proj6a/warping.py:159: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   x = np.linalg.lstsq(A, b)
# /Users/reginaongowarsito/FA18_cs194-26/Proj6a/Proj6a/warping.py:17: RuntimeWarning: divide by zero encountered in double_scalars
#   normCorner = np.dot(corner, 1 / (corner[2]))
# Finding H, done.
# sourceCorners: [[  0   0]
#  [  0 195]
#  [402 195]
#  [402   0]]
# tfSourceCorners: [[-251.33453251  -38.50797685]
#  [-227.56949144  233.97870859]
#  [ 249.90929435  184.68451042]
#  [ 251.31441596   17.49011406]]
# allCorners: [[   0.            0.        ]
#  [   0.          195.        ]
#  [ 402.          195.        ]
#  [ 402.            0.        ]
#  [-251.33453251  -38.50797685]
#  [-227.56949144  233.97870859]
#  [ 249.90929435  184.68451042]
#  [ 251.31441596   17.49011406]]
# (274, 655, -39, -252)
# File saved to: output_imgs/20181122002619_test.png
# /Users/reginaongowarsito/anaconda3/lib/python3.6/site-packages/skimage/util/dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))

# %%
imBase = imSproul0
warpedResults = []
for im in [imSproul0, imSproul1]:
    print("starting for:", im.name)
    print("start: finding H")
    if im.name == imBase.name:
        foundH = np.identity(3)
    else:
        foundH = auto_findH(im, imBase, 300)
    print("end: finding H")
    warpInfo = warpWH(im, foundH)
    warpedResults.append(warpInfo)
result = genImages(warpedResults)
viewImage(alphaBlendingOutput(result))
# printImage("test.png", alphaBlendingOutput(result))

# %%
def iter4(ary):
    for a in range(len(ary) - 3):
        for b in range(a + 1, len(ary) - 2):
            for c in range(b + 1, len(ary) - 1):
                for d in range(c + 1, len(ary)):
                    yield ary[[a, b, c, d]]
    
def findFeaturePairs(featuresImAYX, featuresImBYX, distAB, matchThreshold = 0.5):
    fPairs = []
    
    findMinim2 = lambda a: np.argpartition(a, 2)[:2]
    
    for i in range(len(featuresImAYX)):
        matRow = distAB[i]
        currImAYX = featuresImAYX[i]
        
        NN1stInd, NN2ndInd = findMinim2(matRow)
        
        NN1stYX = featuresImBYX[NN1stInd]
        NN2ndYX = featuresImBYX[NN2ndInd]
        
        NN1stDistVal = matRow[NN1stInd]
        NN2ndDistVal = matRow[NN2ndInd]
        
        if NN1stDistVal/NN2ndDistVal <= matchThreshold:
            fPairs.append((currImAYX, NN1stYX))
    
    return fPairs

# %% [markdown]
# # Scenarios

# %%
def f1():
    imSproul0 = Image.fromPath("../curated_sample_imgs/lower_sproul/lower_sproul_00.jpg", 0.10)
    imSproul0.readCoordsIn("../curated_sample_imgs/lower_sproul/2_lower_sproul_00.txt")

    imSproul1 = Image.fromPath("../curated_sample_imgs/lower_sproul/lower_sproul_01.jpg", 0.10)
    imSproul1.readCoordsIn("../curated_sample_imgs/lower_sproul/2_lower_sproul_01.txt")
    
    imgList = [imSproul0, imSproul1]
    
    printImage("test.png", alphaBlendingOutput(autoWarp(imgList, imSproul0)))
f1()
# Out:
# /Users/reginaongowarsito/anaconda3/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# Calculating for: lower_sproul_00
# Finding H, start.
# Finding H, done.
# sourceCorners: [[  0   0]
#  [  0 195]
#  [402 195]
#  [402   0]]
# tfSourceCorners: [[  0.   0.]
#  [  0. 195.]
#  [402. 195.]
#  [402.   0.]]
# Calculating for: lower_sproul_01
# Finding H, start.
# /Users/reginaongowarsito/FA18_cs194-26/Proj6a/Proj6a/warping.py:159: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   x = np.linalg.lstsq(A, b)
# /Users/reginaongowarsito/FA18_cs194-26/Proj6a/Proj6a/warping.py:17: RuntimeWarning: divide by zero encountered in double_scalars
#   normCorner = np.dot(corner, 1 / (corner[2]))
# Finding H, done.
# sourceCorners: [[  0   0]
#  [  0 195]
#  [402 195]
#  [402   0]]
# tfSourceCorners: [[-251.33453251  -38.50797685]
#  [-227.56949144  233.97870859]
#  [ 249.90929435  184.68451042]
#  [ 251.31441596   17.49011406]]
# allCorners: [[   0.            0.        ]
#  [   0.          195.        ]
#  [ 402.          195.        ]
#  [ 402.            0.        ]
#  [-251.33453251  -38.50797685]
#  [-227.56949144  233.97870859]
#  [ 249.90929435  184.68451042]
#  [ 251.31441596   17.49011406]]
# (274, 655, -39, -252)
# File saved to: output_imgs/20181122002312_test.png
# /Users/reginaongowarsito/anaconda3/lib/python3.6/site-packages/skimage/util/dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
